# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %% [markdown]
# # [作業目標]
# - 仿造範例的MAE函數, 自己寫一個MSE函數(參考上面公式)

# %% [markdown]
# # [作業重點]
# - 注意程式的縮排
# - 是否能將數學公式, 轉換為 Python 的函式組合? (In[2], Out[2])

# %%
# 載入基礎套件與代稱
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# 定義 mean_squared_error 這個函數, 計算並傳回 MSE
def mean_squared_error(y, yp):
    """
    請完成這個 Function 後往下執行
    """
    mse = MSE = (sum(abs(y - yp)) ** 2) / len(y)
    return mse

# %%
# 與範例相同, 不另外解說
w = 3
b = 0.5
x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
# 與範例相同, 不另外解說
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 14163.155
# The Mean absolute error is 11.842

# %% [markdown]
# # [作業2]
#
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# 1. 你選的這組資料為何重要
# Ａ：我選的是一組遊戲銷售的數據，這組數據之所以重要，是因為可以從這組數據去得到例如不同時間區段，玩家對於遊戲的偏好是什麼？是否有改變？改變又是因為什麼？諸如十年前以上的遊戲大多數都較為有挑戰性且需要投入較長遊玩時間，迄今熱銷的遊戲型態是否這樣？如果可以從這組數據去分析，例如寫心得文或者做遊戲影片，就可以產出具有最大價值化的產品。
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# Ａ：提供者是kaggle上的GregorySmith，透過python去爬取vgchartz的網站蒐集而來。
#
# 3. 蒐集而來的資料型態為何
# Ａ：csv
#
# 4. 這組資料想解決的問題如何評估
# Ａ：網上提供者並沒有提出他想解決什麼樣的問題，故這邊以我個人角度發言，例如我去爬取了歷史不同平台遊戲的各地區銷售狀態（含全球），那麼最主要我想解決的問題會是我想去觀察各地區針對遊戲平台偏好、遊戲類型偏好、不同時間維度偏好等，從中去幫助我分析過去至當前形勢，甚至是未來的趨勢，上述就是我會想解決的問題，當然僅有這些資料是還不太夠的（如果有更多其他不同的資料，例如手機誕生後，主機平台又有什麼樣影響，那就可以有更多維度的分析），以上是個人見解與評估。
#
# # [作業3]
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# Ａ：假設市場鎖定國內特定區域情況下，提升業績我的定義是車隊銷售毛利率（意味銷售收入－銷售成本）提高，以下兩種狀況都可以幫助我達到這個目的：
#     1. 收入增加，成本不變;
#     2. 收入不變，成本降低;
#
# 所以我的數據分析最終必須導向這兩個結果，這邊有兩個角度可以切入：
#     1. 收入角度（提高收入）
#     2. 成本角度（降低成本）
#
# 收入角度，比如透過數據分析去增加客戶的體驗、透過數據分析去針對同行競爭對手的比較（找出自身優勢）等
# 成本角度，比如透過數據分析去知道針對現有成本，是否有可降低的方案（例如合作）等
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# Ａ：從opendata / 網站爬取 / 現有API 等來
#
# 3. 蒐集而來的資料型態為何
# Ａ：json, csv
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# Ａ：驗證部分必然是等第一版數據分析出來後凝定方案下去執行後，迭代式進行交叉比對，從中去驗證是否如分析模型所預測的那樣，若沒改善，意味著可能預測的變數有誤，再行修正，從迭代中去改善我們的分析，達到一個最好的結果。
